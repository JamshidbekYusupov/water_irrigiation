# %%
import pandas as pd
import numpy as np
import joblib
import os

# %%
synthetic_data = {
    "Soil_pH": [7.45, 6.92, 5.88, 7.12, 6.55],
    "Soil_Moisture": [18.3, 22.1, 12.7, 35.6, 41.2],
    "Organic_Carbon": [1.12, 0.98, 0.85, 1.25, 1.05],
    "Electrical_Conductivity": [1.35, 2.15, 0.65, 1.75, 2.05],
    "Temperature_C": [24.8, 19.3, 27.1, 16.5, 21.9],
    "Humidity": [48.2, 52.6, 68.3, 71.5, 63.7],
    "Rainfall_mm": [520.4, 1450.8, 35.2, 980.6, 275.3],
    "Sunlight_Hours": [8.7, 5.4, 9.1, 6.2, 7.8],
    "Soil_Type": ["Clay", "Loamy", "Sandy", "Silt", "Clay"],
    "Wind_Speed_kmh": [10.5, 18.2, 14.7, 3.6, 9.9],
    "Crop_Type": ["Sugarcane", "Rice", "Wheat", "Rice", "Potato"],
    "Crop_Growth_Stage": ["Sowing", "Flowering", "Flowering", "Harvest", "Harvest"],
    "Season": ["Zaid", "Kharif", "Rabi", "Rabi", "Zaid"],
    "Irrigation_Type": ["Drip", "Rainfed", "Sprinkler", "Rainfed", "Sprinkler"],
    "Water_Source": ["Groundwater", "Groundwater", "Reservoir", "Groundwater", "Canal"],
    "Field_Area_hectare": [3.2, 6.8, 9.5, 4.7, 5.9],
    "Mulching_Used": ["Yes", "Yes", "No", "No", "Yes"],
    "Previous_Irrigation_mm": [5.4, 42.1, 95.3, 60.7, 28.6],
    "Region": ["South", "South", "West", "North", "East"],
    "Total_Water": [525.8, 1492.9, 130.5, 1041.3, 303.9],
    "Evaporation": [230.45, 95.12, 210.67, 120.33, 140.22],
    "Soil_Fertility": [0.42, 0.27, 0.51, 0.39, 0.31],
    "Heat_Stress": [6.85, 6.55, 7.42, 6.98, 6.73]
}


target = {
    "Irrigation_Need": [1, 1, 2, 2, 1]
}

# %%
X_test = pd.DataFrame(synthetic_data)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Soil_pH                  5 non-null      float64
#  1   Soil_Moisture            5 non-null      float64
#  2   Organic_Carbon           5 non-null      float64
#  3   Electrical_Conductivity  5 non-null      float64
#  4   Temperature_C            5 non-null      float64
#  5   Humidity                 5 non-null      float64
#  6   Rainfall_mm              5 non-null      float64
#  7   Sunlight_Hours           5 non-null      float64
#  8   Soil_Type                5 non-null      object
#  9   Wind_Speed_kmh           5 non-null      float64
#  10  Crop_Type                5 non-null      object
#  11  Crop_Growth_Stage        5 non-null      object
#  12  Season                   5 non-null      object
#  13  Irrigation_Type          5 non-null      object
# ...

# %%
X_test['Previous_Irrigation_mm'] = X_test['Previous_Irrigation_mm'].astype('object')
X_test['Wind_Speed_kmh'] = X_test['Wind_Speed_kmh'].astype('object')
X_test['Field_Area_hectare'] = X_test['Field_Area_hectare'].astype('object')
X_test['Field_Area_hectare'] = X_test['Field_Area_hectare'].astype('object')

# %%
model_path = r'C:\Irrigation_Water_Requirement\Models\all_models\DT.joblib'

model = joblib.load(model_path)

# %%
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scalar',
#                                                                    StandardScaler())]),
#                                                   ['Soil_pH', 'Soil_Moisture',
#                                                    'Organic_Carbon',
#                                                    'Electrical_Conductivity',
#                                                    'Temperature_C', 'Humidity',
#                                                    'Rainfall_mm',
#                                                    'Sunlight_Hours']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encode',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
# ...

# %%
# X_test = model.named_steps['preprocessor'].transform()
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 2, 0, 1, 1])

# %%
target
# Out:
# {'Irrigation_Need': [1, 1, 2, 2, 1]}

# %% [markdown]
# # As our offline testing set is sythetic made,it is possible that some error will occur
